# %% [markdown]
# This is a sample of how to get the api key and run the Gemini api key inside of my code. This costs money to run!!! So only run when needed.

# %%
import google.generativeai as genai
import getpass
import os

# Securely get your API key
# When you run this, it will give you a password box to paste your key into.
if 'GOOGLE_API_KEY' in os.environ:
    api_key = os.environ['GOOGLE_API_KEY']
else:
    api_key = getpass.getpass("Enter your Google AI Studio API Key: ")

genai.configure(api_key=api_key)

# Check available models
print("--- Available Models ---")
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
print("------------------------\n")


# --- Your First Prompt ---

# Initialize the model (using gemini-2.5-flash for a fast, capable model) below will cost money to run
#model = genai.GenerativeModel('gemini-2.5-flash')

# Send a prompt
#response = model.generate_content("What are 3 key challenges when building a two-sided data marketplace?")

# Print the response
#print(response.text)
